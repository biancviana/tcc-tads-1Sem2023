# %%
import pandas as pd

# carrega dataset original
df = pd.read_csv('datasets/bullying_clean_new.csv', sep=',')
df
# Out:
#       Escola      Curso    Cor      Genero  Ano  Idade         Demora dormir  \
# 0       ETIM  Integrado  Branca  Masculino    1     15  > 3 vezes por semana
# 1       ETIM  Integrado   Parda   Feminino    1     15  2-3 vezes por semana
# 2       ETIM  Integrado  Branca   Feminino    1     16  > 3 vezes por semana
# 3       ETIM  Integrado  Branca  Masculino    1     15  > 3 vezes por semana
# 4       ETIM  Integrado  Branca   Feminino    1     15  1-2 vezes por semana
# ..       ...        ...     ...        ...  ...    ...                   ...
# 484  ETEC-HM   Conc-Sub   Parda   Feminino    1     19  > 3 vezes por semana
# 485  ETEC-HM   Conc-Sub   Parda   Feminino    1     18    < 1 vez por semana
# 486  ETEC-HM   Conc-Sub   Parda  Masculino    1     19  > 3 vezes por semana
# 487  ETEC-HM   Conc-Sub  Branca  Masculino    1     18  2-3 vezes por semana
# 488  ETEC-HM   Conc-Sub   Negra  Masculino    1     19  2-3 vezes por semana
#
# ...

# %%
# dividindo o dataset entre treino e teste
from sklearn.model_selection import train_test_split

df_train, df_test = train_test_split(df, train_size=0.8, random_state=42)

# %%
# salva o dataframe de treino e teste

#df_train.to_csv('datasets/new-bullying_notamedia_train.csv')
#df_test.to_csv('datasets/new-bullying_notamedia_test.csv')
